# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                      Job Title  \
# 0                      Digital Project Manager
# 1  Construction Project Coordinator - Low Rise
# 2          Project Manager Housing Development
# 3    Construction Quality Assurance Technician
# 4                                 Site Manager
#
#                   Salary Estimate  \
# 0  CA$30k-CA$61k (Glassdoor Est.)
# 1  CA$30k-CA$61k (Glassdoor Est.)
# 2  CA$30k-CA$61k (Glassdoor Est.)
# 3  CA$30k-CA$61k (Glassdoor Est.)
# 4  CA$30k-CA$61k (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  As a Digital Project Manager at Thinkwell Stud...     3.4
# 1  Saturday, May 9, 2020\n\nWe are proud to be on...     4.5
# 2  Temporary Duration: 24 months\nSalary Range: $...    -1.0
# 3  Saturday, May 9, 2020\n\nWe are proud to be on...     4.5
# 4  Site Manager\n# of openings\n\n1\n\nCity\n\n\n...     4.3
#
#                Company Name       Location Country     Headquarters  \
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'age', 'pmp_yn', 'agile_yn', 'excel', 'primavera',
#        'job_simp', 'seniority'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'construction manager' in title.lower():
        return 'construction manager'
    elif 'project manager' in title.lower():
        return 'porject manager'
    elif 'construction manager' and 'project' in title.lower():
        return 'construction manager'
    elif 'project coordinator' in title.lower():
        return 'project coordinator'
    elif 'internship' in title.lower():
        return 'internship'
    elif 'superintendent' in title.lower():
        return 'construction manager'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# porject manager         645
# na                      148
# construction manager    105
# internship                2
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        792
# senior    106
# jr          2
# Name: seniority, dtype: int64

# %%
#  Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2704
# 1      2642
# 2      5205
# 3      3218
# 4      2074
#        ...
# 895    7057
# 896    2244
# 897    2241
# 898    5930
# 899    6195
# Name: desc_len, Length: 900, dtype: int64

# %%
#Competitor count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df['Competitors']
# Out:
# 0                                                  -1
# 1                                                  -1
# 2                                                  -1
# 3                                                  -1
# 4      Public Storage, Extra Space Storage, CubeSmart
#                             ...
# 895                                                -1
# 896                                                -1
# 897                                                -1
# 898                                                -1
# 899                                                -1
# Name: Competitors, Length: 900, dtype: object

# %%
#hourly wage to annual 

#df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
#df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
#df[df.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
# Empty DataFrame
# Columns: [hourly, min_salary, max_salary]
# Index: []

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0               Thinkwell Group
# 1            Empire Communities
# 2      Niagara Regional Housing
# 3            Empire Communities
# 4                   StorageMart
#                  ...
# 895                   TC Energy
# 896           United Landscapes
# 897       RailWorks Corporation
# 898          Innomar Strategies
# 899                 Ocado Group
# Name: company_txt, Length: 900, dtype: object

# %%
from geopy import geocoders
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="data_cleaning")
location = geolocator.geocode('montreal canada')
location
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-f97225c6c43f> in <module>
#       2 from geopy.geocoders import Nominatim
#       3 geolocator = Nominatim(user_agent="data_cleaning")
# ----> 4 location = geolocator.geocode(('Coquitlam', 'Canada'))
#       5 location
#
# ~/opt/anaconda3/envs/ss/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     323             }
#     324         else:
# --> 325             params = {'q': self.format_string % query}
#     326
#     327         params.update({
#
# TypeError: not all arguments converted during string formatting

# %%
# def get_coordinates(city, timeout=5):
#     """
#     Geolocate an address.

#     Returns the latitude and longitude of the given address using
#     OpenStreetMap's Nominatim service. If the coordinates of the
#     address cannot be found then ``(None, None)`` is returned.

#     As per Nominatim's terms of service this function is rate limited
#     to at most one call per second.

#     ``timeout`` gives the timeout in seconds.
#     """
#     location = geolocator.geocode(city, timeout=timeout)
#     if not location:
#         return None, None
#     return location.latitude, location.longitude

# %%
# geo= geolocator.geocode("Montreal,Canada")
# print(geo.latitude, geo.longitude)
# df2=pd.DataFrame({'Latitude':[geo.latitude], 'Longitude':[geo.longitude]})
# for index, row in df.iterrows():
#     #geo=geolocator.geocode[]
#     print(row['Location'],row['Country'])
#     df2=pd.DataFrame({'Latitude':[geo.latitude], 'Longitude':[geo.longitude]})
for index, row in df.iterrows():
    #geo=geolocator.geocode[]
    address= (row['Location'],row["Country"]
    print(address)
# Out:
#   File "<ipython-input-107-f7c7642bb1e4>", line 11
#     print(address)
#         ^
# SyntaxError: invalid syntax

# %%
for index, row in df.iterrows():
    #geo=geolocator.geocode[]
    address=row['Location'],row['Country']
    geo= geolocator.geocode(row['Location'],row['Country'])
#     df2=pd.DataFrame({'Latitude':[geo.latitude], 'Longitude':[geo.longitude]})
# df=df.append(df2)

# %%
geo.latitude
# Out:
# 46.3144754

# %%
df.describe()
# Out:
#            Founded   Latitude  Longitude      Rating         age    agile_yn  \
# count   900.000000   1.000000   1.000000  900.000000  900.000000  900.000000
# mean    922.850000  45.497216 -73.610364    2.280778   23.243333    0.081111
# std     984.241855        NaN        NaN    2.261453   39.544932    0.273157
# min      -1.000000  45.497216 -73.610364   -1.000000   -1.000000    0.000000
# 25%      -1.000000  45.497216 -73.610364   -1.000000   -1.000000    0.000000
# 50%      -1.000000  45.497216 -73.610364    3.300000   -1.000000    0.000000
# 75%    1982.000000  45.497216 -73.610364    4.000000   31.000000    0.000000
# max    2019.000000  45.497216 -73.610364    5.000000  355.000000    1.000000
#
#        avg_salary  employer_provided       excel  hourly  max_salary  \
# count  900.000000              900.0  900.000000   900.0  900.000000
# mean    83.933333                0.0    0.630000     0.0  100.066667
# ...

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Country', 'Founded', 'Headquarters',
#        'Industry', 'Job Description', 'Job Title', 'Latitude', 'Location',
#        'Longitude', 'Rating', 'Revenue', 'Salary Estimate', 'Sector', 'Size',
#        'Type of ownership', 'age', 'agile_yn', 'avg_salary', 'company_txt',
#        'employer_provided', 'excel', 'hourly', 'job_simp', 'max_salary',
#        'min_salary', 'pmp_yn', 'primavera', 'seniority'],
#       dtype='object')

# %%
df['Latitude']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 896          NaN
# 897          NaN
# 898          NaN
# 899          NaN
# 0      45.497216
# Name: Latitude, Length: 901, dtype: float64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv')
